# %% [markdown]
# <a href="https://colab.research.google.com/github/rahulgam187/MyLearnings/blob/master/run-and-share-comfyui-on-google-colab.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Running ComfyUI in Google Colab
#
# To run ComfyUI in Google Colab, you need to enable GPU acceleration. Go to "Runtime" -> "Change runtime type" and select "GPU" as the hardware accelerator.

# %%
from google.colab import drive
drive.mount('/content/drive')

# %%
# Update package lists and install necessary packages
# !apt-get update
# !apt-get install -y wget aria2 libgl1-mesa-glx

# %%
# Clone the ComfyUI repository from GitHub
# !git clone https://github.com/comfyanonymous/ComfyUI.git

# %%
# Change the current directory to ComfyUI and install required Python packages
# %cd ComfyUI
# !pip install -r requirements.txt

# %%
# Install the pinggy library for creating public URLs
# !pip install pinggy

# %%
# Start a pinggy tunnel to forward traffic from a public URL to localhost:8188
import pinggy
tunnel1 = pinggy.start_tunnel(
    forwardto="localhost:8188",
)

# Print the URLs of the started tunnel
print(f"Tunnel1 started - URLs: {tunnel1.urls}")

# %%
# 1. Go to the exact folder where custom nodes live
# %cd /content/ComfyUI/custom_nodes/

# 2. Wipe any broken folders and freshly install the Animation and Video nodes
# !rm -rf ComfyUI-AnimateDiff-Evolved ComfyUI-VideoHelperSuite
# !git clone https://github.com/Kosinkadink/ComfyUI-AnimateDiff-Evolved.git
# !git clone https://github.com/Kosinkadink/ComfyUI-VideoHelperSuite.git

# 3. Install the necessary math libraries
# !pip install einops onnxruntime

# 4. Make sure the 1.6GB motion engine is inside the new folder
# !mkdir -p /content/ComfyUI/custom_nodes/ComfyUI-AnimateDiff-Evolved/models/
# !wget -nc https://huggingface.co/guoyww/animatediff/resolve/main/mm_sd_v15_v2.ckpt -P /content/ComfyUI/custom_nodes/ComfyUI-AnimateDiff-Evolved/models/
# 1. Create the correct folder for base models
# !mkdir -p /content/ComfyUI/models/checkpoints/
# 2. Download the AnyLoRA base model (This fixes the Error 400)
# !wget -c https://huggingface.co/Lykon/AnyLoRA/resolve/main/AnyLoRA_noVae_fp16-pruned.safetensors -P /content/ComfyUI/models/checkpoints/

# %%
# %cd /content/ComfyUI

# %%
# Run the main ComfyUI application, listening on all network interfaces
# !python main.py --listen 0.0.0.0 --output-directory /content/drive/MyDrive/AnimeTest
